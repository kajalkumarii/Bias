# %%
from typing import List
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt
from scipy.signal import find_peaks
import os
import gzip
from tqdm import tqdm
import seaborn as sns
import natsort
from scipy.signal import savgol_filter
import hashlib

# %%
def read_files(folder_path):
    all_files = glob.glob(os.path.join(folder_path, "*.csv.gz"))
    all_files = natsort.natsorted(all_files)  # Natural sort files

    fish_data = {}

    for file_path in all_files:
        filename = os.path.basename(file_path)
        fish_id, trial_id = filename.split('_')[0], filename.split('_')[1]

        # Only process the first 3 trials for each fish
        if fish_id not in fish_data:
            fish_data[fish_id] = {}
        if trial_id not in fish_data[fish_id] and len(fish_data[fish_id]) < 3:
            fish_data[fish_id][trial_id] = file_path

    # Debug: Print out the files being processed for each fish
    for fish_id, trials in fish_data.items():
        print(f"Fish ID: {fish_id}, Trials: {list(trials.keys())}")

    return fish_data

# %%
def calculate_time_stamp(df):
    df['time_stamp'] = (df['realtime'] - df['start_time'][0]) / 100
    return df

# %%
def cartesian_to_spherical(x, y, z):
    r = np.sqrt(x**2 + y**2 + z**2)
    theta = np.arctan2(y, x)  # Azimuth
    phi = np.arccos(z / r)    # Inclination
    return r, theta, phi

def spherical_to_cartesian(r, theta, phi):
    x = r * np.sin(phi) * np.cos(theta)
    y = r * np.sin(phi) * np.sin(theta)
    z = r * np.cos(phi)
    return x, y, z

# %%
def filter_large_jumps(df, max_stepsize=0.02, window_size=10):
    # Calculate the step size for each frame
    steps = np.sqrt(df['fishx'].diff()**2 + df['fishy'].diff()**2 + df['fishz'].diff()**2)
    
    # Identify large steps
    large_steps = steps > max_stepsize
    large_step_indices = large_steps[large_steps].index.values

    # print first 5 large steps

    print(f"Found {len(large_step_indices)} large steps")

    # Filter out the large steps
    for index in large_step_indices:
        df.loc[index-window_size:index+window_size, ['fishz', 'fishy', 'fishx']] = np.nan

    return df

# %%
# print length of df

# %%
def filter_spherical(df, err=0.005, z_offset=0.11):
    # Convert to spherical coordinates
    azimuth, elevation, R = cartesian_to_spherical(df['fishx'], df['fishy'], df['fishz'] - z_offset)

    # Apply spherical filters
    df.loc[R > 0.2 + err, ['fishz', 'fishy', 'fishx']] = np.nan
    df.loc[R < 0.11 - err, ['fishz', 'fishy', 'fishx']] = np.nan

    return df

# %%
def calculate_angles_at_peaks_efficient(df, fHz):
    # Find peaks
    peaks, _ = find_velocity_peaks(df, fHz)

    # Calculate angles at peaks
    peak_angles = [calculate_angle(df, peaks[i-1], peaks[i]) for i in range(1, len(peaks))]

    df['peak_angles'] = np.nan

    # Assign values to the rows corresponding to the peak indices
    df.loc[peaks[1:], 'peak_angles'] = peak_angles  # Skip the first peak as there's no angle for it

    # print("Unique peak_angles: ", df['peak_angles'].unique())

    # Handle timestamps, interbout durations, and turn bias
    df['time_stamp_peak'] = np.nan
    df.loc[peaks, 'time_stamp_peak'] = df.loc[peaks, 'time_stamp']

    df['interbout_duration'] = np.nan
    df.loc[peaks[1:], 'interbout_duration'] = df.loc[peaks[1:], 'time_stamp'] - df.loc[peaks[:-1], 'time_stamp'].values

    angle_differences = np.diff(peak_angles)
    turn_bias = np.sign(angle_differences)
    turn_bias = np.append(turn_bias, np.nan)  # Append NaN to match lengths
    df.loc[peaks[1:], 'turn_bias'] = turn_bias


    # # print unique df.time_stamp_peak and df.interbout_duration
    # print("Unique time_stamp_peak: ", df['time_stamp_peak'].unique())
    # print("Unique interbout_duration: ", df['interbout_duration'].unique())

    return df, peaks, peak_angles

# %%
def calculate_angle(df, prev_peak, current_peak):
    v1 = df.loc[prev_peak, ['dx', 'dy']]
    v2 = df.loc[current_peak, ['dx', 'dy']]

    angle_rad = np.arctan2(v2[1] - v1[1], v2[0] - v1[0])  # Difference in dy and dx
    angle_degrees = np.degrees(angle_rad)
    # center angle between -180 and 180
    angle_degrees = (angle_degrees + 180) % 360 - 180
    # save angle_degrees to df
    df.loc[current_peak, 'angle_degrees'] = angle_degrees

    return angle_degrees

# %%
def calculate_cumulative_angles(df, peaks):
    # Calculate angles at peaks (as per your Method 1)
    peak_angles = calculate_angles_at_peaks_efficient(df, peaks)
    
    # Calculate cumulative angles
    cumulative_angles = np.cumsum(peak_angles)

    return cumulative_angles

# %%
def find_velocity_peaks(df, fHz):
    height_min, height_max = 0.015, 0.4
    distance = round(fHz / 10)
    width = round(fHz / 100)
    prominence = 0.03

    peaks, properties = find_peaks(df['velocity'], height=(height_min, height_max), 
                                   distance=distance, width=width, prominence=prominence)
    
    # print first 5 peaks

    print(peaks[:5])

    # # plot the peaks and the velocity
    # plt.figure(figsize=(20, 10))
    # plt.plot(df['velocity'], label='velocity')
    # plt.plot(peaks, df['velocity'][peaks], "x")
    # plt.title('Velocity and peaks')
    # plt.legend()
    # plt.show()

    print(f"Found {len(peaks)} peaks")
    return peaks, properties

# %%
def process_file(file_path, fHz=100):
    # Load the data
    desired_cols = ['realtime', 'fishx', 'fishy', 'fishz', 'start_time']
    df = pd.read_csv(file_path, compression='gzip', usecols=desired_cols)#, nrows=2000)
    
    # Apply filters
    df = filter_large_jumps(df)

    # df = filter_spherical(df)

    # Smooth the data using savgol_filter
    df['smooth_fishx'] = savgol_filter(df['fishx'], 11, 1)
    df['smooth_fishy'] = savgol_filter(df['fishy'], 11, 1)
    df['smooth_fishz'] = savgol_filter(df['fishz'], 11, 1)

    # Calculate the differences on the smoothed data
    df['dx'] = df['smooth_fishx'].diff().fillna(0)
    df['dy'] = df['smooth_fishy'].diff().fillna(0)
    df['dz'] = df['smooth_fishz'].diff().fillna(0)
    
    df['velocity'] = np.sqrt(df['dx']**2 + df['dy']**2 + df['dz']**2) / (1/fHz)

    #  add time_stamp column
    df = calculate_time_stamp(df)

    #  Call calculate_angles_at_peaks_efficient to get peaks and related calculations
    df, peaks, peak_angles = calculate_angles_at_peaks_efficient(df, fHz)

    # Center angles from -180 to 180 degrees and unwrap them
    wrapped_angles = [(angle + 180) % 360 - 180 for angle in peak_angles]
    unwrapped_angles = np.unwrap(np.radians(wrapped_angles))

    # Calculate cumulative angles
    cumulative_angles = np.cumsum(np.degrees(unwrapped_angles))

    # print(df.tail())

    # Other calculations such as interbout duration, turn bias, etc., are included in calculate_angles_at_peaks_efficient

    return df, peaks, peak_angles, wrapped_angles, unwrapped_angles, cumulative_angles

# %%
def aggregate_trial_results(fish_data, fHz):
    aggregated_data = {}
    for fish_id, trials in fish_data.items():
        aggregated_data[fish_id] = {'turn_bias_per_trial': {}}
        for trial_id, file_path in trials.items():
            df, peaks, _, _, turn_bias = process_file(file_path, fHz)
            left_turns = np.sum(np.array(turn_bias) == -1)
            right_turns = np.sum(np.array(turn_bias) == 1)
            total_turns = len(turn_bias) - 1  # Subtracting 1 for the appended NaN
            left_turn_prop = left_turns / total_turns if total_turns > 0 else 0
            right_turn_prop = right_turns / total_turns if total_turns > 0 else 0
            aggregated_data[fish_id]['turn_bias_per_trial'][trial_id] = {
                'left_turn_prop': left_turn_prop,
                'right_turn_prop': right_turn_prop
                
            }

    return aggregated_data

# %%
def aggregate_fish_results(fish_data, fHz):
    aggregated_data = {}
    for fish_id, trials in fish_data.items():
        for trial_id, file_path in trials.items():
            df, peaks, peak_angles, wrapped_angles, unwrapped_angles, cumulative_angles = process_file(file_path, fHz)
            aggregated_data[file_path] = {  # Use file_path as the key
                'df': df,
                'peaks': peaks,
                'peak_angles': peak_angles,
                'wrapped_angles': wrapped_angles,
                'unwrapped_angles': unwrapped_angles,
                'cumulative_angles': cumulative_angles
                
        }
    return aggregated_data

# %%
def extract_fish_trial(full_path):
    """
    Extracts fish ID and trial number from the full file path.
    Assumes the filename is in a format like 'FishID_TrialNumber_otherinfo.csv.gz'.
    """
    # Extract the filename from the full path
    filename = os.path.basename(full_path)
    print(f"Debug: Extracted filename: {filename}")  # Debug print

    parts = filename.split('_')
    print(f"Debug: Split parts: {parts}")  # Debug print

    if len(parts) >= 2:
        # Extract Fish ID and Trial Number
        fish_id, trial = parts[0], parts[1]
        return fish_id, trial
    return 'Unknown', 'Unknown'

def save_dataframe(df, output_folder_path, file_name):
    """
    Saves the given dataframe.
    """
    full_path = os.path.join(output_folder_path, file_name)
    print(f"Debug: Saving dataframe to {full_path}")  # Debug print

    df.to_csv(full_path, index=False)
    print(f"Dataframe saved as '{full_path}'")

def save_dataframes_from_nested_dict(nested_dict, output_folder_path, file_name_suffix):
    """
    Iterates over a nested dictionary of dataframes and saves each dataframe.
    """
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder_path):
        os.makedirs(output_folder_path)

    for outer_key, inner_dict in nested_dict.items():
        if isinstance(inner_dict, dict):
            for inner_key, df in inner_dict.items():
                if isinstance(df, pd.DataFrame):
                    fish_id, trial = extract_fish_trial(outer_key)
                    file_identifier = f'{fish_id}_{trial}' if fish_id != 'Unknown' and trial != 'Unknown' else 'Unknown_Unknown'
                    file_name = f'{file_identifier}_{inner_key}_{file_name_suffix}.csv'
                    save_dataframe(df, output_folder_path, file_name)
                else:
                    print(f"Skipping non-dataframe item for key: {inner_key} in nested dict of {outer_key}")
        else:
            print(f"Skipping non-dict item for key: {outer_key}")

# %%
fHz = 100  # or the appropriate value for your data
folder_path = "/home/kkumari/PhD/fish-data/long-term-free-swim/"
# Read files from folder and organize by fish and trial
fish_data = read_files(folder_path)
# Aggregate results across trials for each fish
# trial_results = aggregate_trial_results(fish_data, fHz)
# Aggregate results across different fishes
fish_results = aggregate_fish_results(fish_data, fHz)
# Out:
# Fish ID: 01, Trials: ['T1', 'T2', 'T3']
# Fish ID: 02, Trials: ['T1', 'T2', 'T3']
# Fish ID: 03, Trials: ['T1', 'T2', 'T4']
# Fish ID: 04, Trials: ['T1', 'T2', 'T3']
# Fish ID: 05, Trials: ['T1', 'T2', 'T3']
# Fish ID: 06, Trials: ['T1', 'T2', 'T3']
# Fish ID: 07, Trials: ['T1', 'T2', 'T3']
# Fish ID: 08, Trials: ['T1', 'T2', 'T3']
# Fish ID: 09, Trials: ['T1', 'T2', 'T3']
# Fish ID: 10, Trials: ['T1', 'T2', 'T3']
# Fish ID: 11, Trials: ['T1', 'T2', 'T3']
# Fish ID: 12, Trials: ['T1', 'T2', 'T3']
# Fish ID: 13, Trials: ['T1', 'T2', 'T3']
# Fish ID: 14, Trials: ['T1', 'T2', 'T3']
# Fish ID: 15, Trials: ['T1', 'T2', 'T3']
# Fish ID: 16, Trials: ['T1', 'T2', 'T3']
# Found 447 large steps
# [22 47 58 78 93]
# Found 14911 peaks
# Found 1068 large steps
# [ 39  96 110 138 160]
# Found 12431 peaks
# Found 711 large steps
# [ 19  46  86 106 135]
# Found 15081 peaks
# Found 193 large steps
# [ 13  36  71 113 141]
# Found 15657 peaks
# Found 346 large steps
# [ 16  50  70  99 126]
# Found 15648 peaks
# Found 197 large steps
# [ 12  34  71 108 151]
# Found 15964 peaks
# Found 67 large steps
# [ 13  41  61  82 106]
# Found 12216 peaks
# Found 415 large steps
# [ 12  42  77 145 165]
# Found 14857 peaks
# Found 326 large steps
# [ 19  67  87 103 121]
# Found 14505 peaks
# Found 69 large steps
# [ 12  23  44 117 162]
# Found 13360 peaks
# Found 31 large steps
# [ 29  62 115 153 188]
# Found 14480 peaks
# Found 5 large steps
# [ 39 123 170 312 351]
# Found 13454 peaks
# Found 210 large steps
# [ 42  91 126 164 226]
# Found 11244 peaks
# Found 312 large steps
# [ 13  33 132 153 183]
# Found 14295 peaks
# Found 244 large steps
# [ 20  50  75  89 116]
# Found 16136 peaks
# Found 226 large steps
# [ 13  53 116 179 213]
# Found 11152 peaks
# Found 87 large steps
# [ 13  45  88 118 147]
# Found 10967 peaks
# Found 825 large steps
# [ 23  92 121 148 177]
# Found 10904 peaks
# Found 178 large steps
# [ 27  96 152 182 234]
# Found 11529 peaks
# Found 116 large steps
# [ 39 179 205 226 267]
# Found 12582 peaks
# Found 40 large steps
# [  5  31  58  91 120]
# Found 12701 peaks
# Found 31 large steps
# [ 44  81 122 199 390]
# Found 12463 peaks
# Found 17 large steps
# [ 43  72 121 145 176]
# Found 12367 peaks
# Found 29 large steps
# [ 11  59 130 169 204]
# Found 12579 peaks
# Found 157 large steps
# [ 33  75  91 138 212]
# Found 9511 peaks
# Found 211 large steps
# [ 12  40  84 129 183]
# Found 10107 peaks
# Found 548 large steps
# [19 32 55 80 90]
# Found 13124 peaks
# Found 217 large steps
# [ 27  73 218 242 276]
# Found 11516 peaks
# Found 471 large steps
# [ 27  76 141 199 234]
# Found 12223 peaks
# Found 538 large steps
# [ 55 120 189 256 302]
# Found 12048 peaks
# Found 69 large steps
# [ 14  63 104 126 155]
# Found 12618 peaks
# Found 121 large steps
# [ 24  48  95 145 213]
# Found 14524 peaks
# Found 93 large steps
# [ 14  30  41  87 131]
# Found 15675 peaks
# Found 77 large steps
# [ 30  77 132 154 190]
# Found 13480 peaks
# Found 390 large steps
# [ 13  48  88 127 162]
# Found 9339 peaks
# Found 615 large steps
# [ 23  71 108 126 151]
# Found 9174 peaks
# Found 269 large steps
# [ 75 130 177 230 281]
# Found 11640 peaks
# Found 568 large steps
# [ 47  79 122 165 252]
# Found 10855 peaks
# Found 668 large steps
# [ 19  60  97 132 169]
# Found 11678 peaks
# Found 155 large steps
# [ 33  87 147 193 218]
# Found 13237 peaks
# Found 110 large steps
# [ 52 114 129 146 172]
# Found 13271 peaks
# Found 124 large steps
# [ 13  55 159 191 248]
# Found 13082 peaks
# Found 52 large steps
# [ 15  60 112 212 233]
# Found 12702 peaks
# Found 43 large steps
# [ 27  68 103 130 142]
# Found 12709 peaks
# Found 121 large steps
# [ 17  64  87 123 168]
# Found 13282 peaks
# Found 12 large steps
# [ 12  50  78 111 142]
# Found 11589 peaks
# Found 32 large steps
# [ 12  96 133 167 199]
# Found 13354 peaks
# Found 19 large steps
# [ 13  96 150 236 253]
# Found 12837 peaks

# %%
print(type(fish_results))
# Out:
# <class 'dict'>

# %%
for key in list(fish_results.keys())[:5]:  # Adjust the number to print more or fewer keys
    print(f"Key: {key}, Type of value: {type(fish_results[key])}")
# Out:
# Key: /home/kkumari/PhD/fish-data/long-term-free-swim/01_T1_1b8cd8200e6211edb285003053fc6914_VR03.csv.gz, Type of value: <class 'dict'>
# Key: /home/kkumari/PhD/fish-data/long-term-free-swim/01_T2_667418920e7311edb1af003053fc6914_VR03.csv.gz, Type of value: <class 'dict'>
# Key: /home/kkumari/PhD/fish-data/long-term-free-swim/01_T3_cf108f460e8411edb1af003053fc6914_VR03.csv.gz, Type of value: <class 'dict'>
# Key: /home/kkumari/PhD/fish-data/long-term-free-swim/02_T1_1ce42cc80e6211ed9279003053fc8758_VR04.csv.gz, Type of value: <class 'dict'>
# Key: /home/kkumari/PhD/fish-data/long-term-free-swim/02_T2_683acd880e7311edb6c7003053fc8758_VR04.csv.gz, Type of value: <class 'dict'>

# %%
all(isinstance(value, pd.DataFrame) for value in fish_results.values())
# Out:
# False

# %%
print(f"Number of keys in fish_results: {len(fish_results)}")
print(f"Types of values: {set(type(value) for value in fish_results.values())}")
# Out:
# Number of keys in fish_results: 48
# Types of values: {<class 'dict'>}

# %%
output_folder_path = "/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/"
file_name_suffix = 'processed-data'
save_dataframes_from_nested_dict(fish_results, output_folder_path, file_name_suffix)
# Out:
# Debug: Extracted filename: 01_T1_1b8cd8200e6211edb285003053fc6914_VR03.csv.gz
# Debug: Split parts: ['01', 'T1', '1b8cd8200e6211edb285003053fc6914', 'VR03.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/01_T1_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/01_T1_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/01_T1_1b8cd8200e6211edb285003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/01_T1_1b8cd8200e6211edb285003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/01_T1_1b8cd8200e6211edb285003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/01_T1_1b8cd8200e6211edb285003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/01_T1_1b8cd8200e6211edb285003053fc6914_VR03.csv.gz
# Debug: Extracted filename: 01_T2_667418920e7311edb1af003053fc6914_VR03.csv.gz
# Debug: Split parts: ['01', 'T2', '667418920e7311edb1af003053fc6914', 'VR03.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/01_T2_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/01_T2_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/01_T2_667418920e7311edb1af003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/01_T2_667418920e7311edb1af003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/01_T2_667418920e7311edb1af003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/01_T2_667418920e7311edb1af003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/01_T2_667418920e7311edb1af003053fc6914_VR03.csv.gz
# Debug: Extracted filename: 01_T3_cf108f460e8411edb1af003053fc6914_VR03.csv.gz
# Debug: Split parts: ['01', 'T3', 'cf108f460e8411edb1af003053fc6914', 'VR03.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/01_T3_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/01_T3_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/01_T3_cf108f460e8411edb1af003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/01_T3_cf108f460e8411edb1af003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/01_T3_cf108f460e8411edb1af003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/01_T3_cf108f460e8411edb1af003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/01_T3_cf108f460e8411edb1af003053fc6914_VR03.csv.gz
# Debug: Extracted filename: 02_T1_1ce42cc80e6211ed9279003053fc8758_VR04.csv.gz
# Debug: Split parts: ['02', 'T1', '1ce42cc80e6211ed9279003053fc8758', 'VR04.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/02_T1_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/02_T1_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/02_T1_1ce42cc80e6211ed9279003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/02_T1_1ce42cc80e6211ed9279003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/02_T1_1ce42cc80e6211ed9279003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/02_T1_1ce42cc80e6211ed9279003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/02_T1_1ce42cc80e6211ed9279003053fc8758_VR04.csv.gz
# Debug: Extracted filename: 02_T2_683acd880e7311edb6c7003053fc8758_VR04.csv.gz
# Debug: Split parts: ['02', 'T2', '683acd880e7311edb6c7003053fc8758', 'VR04.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/02_T2_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/02_T2_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/02_T2_683acd880e7311edb6c7003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/02_T2_683acd880e7311edb6c7003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/02_T2_683acd880e7311edb6c7003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/02_T2_683acd880e7311edb6c7003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/02_T2_683acd880e7311edb6c7003053fc8758_VR04.csv.gz
# Debug: Extracted filename: 02_T3_d07165360e8411edb6c7003053fc8758_VR04.csv.gz
# Debug: Split parts: ['02', 'T3', 'd07165360e8411edb6c7003053fc8758', 'VR04.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/02_T3_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/02_T3_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/02_T3_d07165360e8411edb6c7003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/02_T3_d07165360e8411edb6c7003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/02_T3_d07165360e8411edb6c7003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/02_T3_d07165360e8411edb6c7003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/02_T3_d07165360e8411edb6c7003053fc8758_VR04.csv.gz
# Debug: Extracted filename: 03_T1_1e11355a0e6211ed903c003053fc769c_VR05.csv.gz
# Debug: Split parts: ['03', 'T1', '1e11355a0e6211ed903c003053fc769c', 'VR05.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/03_T1_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/03_T1_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/03_T1_1e11355a0e6211ed903c003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/03_T1_1e11355a0e6211ed903c003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/03_T1_1e11355a0e6211ed903c003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/03_T1_1e11355a0e6211ed903c003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/03_T1_1e11355a0e6211ed903c003053fc769c_VR05.csv.gz
# Debug: Extracted filename: 03_T2_69643ba40e7311eda834003053fc769c_VR05.csv.gz
# Debug: Split parts: ['03', 'T2', '69643ba40e7311eda834003053fc769c', 'VR05.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/03_T2_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/03_T2_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/03_T2_69643ba40e7311eda834003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/03_T2_69643ba40e7311eda834003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/03_T2_69643ba40e7311eda834003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/03_T2_69643ba40e7311eda834003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/03_T2_69643ba40e7311eda834003053fc769c_VR05.csv.gz
# Debug: Extracted filename: 03_T4_555015520e9611eda834003053fc769c_VR05.csv.gz
# Debug: Split parts: ['03', 'T4', '555015520e9611eda834003053fc769c', 'VR05.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/03_T4_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/03_T4_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/03_T4_555015520e9611eda834003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/03_T4_555015520e9611eda834003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/03_T4_555015520e9611eda834003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/03_T4_555015520e9611eda834003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/03_T4_555015520e9611eda834003053fc769c_VR05.csv.gz
# Debug: Extracted filename: 04_T1_1f4eb4ce0e6211ed984a003053fc7678_VR06.csv.gz
# Debug: Split parts: ['04', 'T1', '1f4eb4ce0e6211ed984a003053fc7678', 'VR06.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/04_T1_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/04_T1_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/04_T1_1f4eb4ce0e6211ed984a003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/04_T1_1f4eb4ce0e6211ed984a003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/04_T1_1f4eb4ce0e6211ed984a003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/04_T1_1f4eb4ce0e6211ed984a003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/04_T1_1f4eb4ce0e6211ed984a003053fc7678_VR06.csv.gz
# Debug: Extracted filename: 04_T2_6b25ac480e7311edb02a003053fc7678_VR06.csv.gz
# Debug: Split parts: ['04', 'T2', '6b25ac480e7311edb02a003053fc7678', 'VR06.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/04_T2_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/04_T2_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/04_T2_6b25ac480e7311edb02a003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/04_T2_6b25ac480e7311edb02a003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/04_T2_6b25ac480e7311edb02a003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/04_T2_6b25ac480e7311edb02a003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/04_T2_6b25ac480e7311edb02a003053fc7678_VR06.csv.gz
# Debug: Extracted filename: 04_T3_d2dff35a0e8411edb02a003053fc7678_VR06.csv.gz
# Debug: Split parts: ['04', 'T3', 'd2dff35a0e8411edb02a003053fc7678', 'VR06.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/04_T3_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/04_T3_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/04_T3_d2dff35a0e8411edb02a003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/04_T3_d2dff35a0e8411edb02a003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/04_T3_d2dff35a0e8411edb02a003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/04_T3_d2dff35a0e8411edb02a003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/04_T3_d2dff35a0e8411edb02a003053fc7678_VR06.csv.gz
# Debug: Extracted filename: 05_T1_67b4c062170111edae5c003053fc6914_VR03.csv.gz
# Debug: Split parts: ['05', 'T1', '67b4c062170111edae5c003053fc6914', 'VR03.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/05_T1_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/05_T1_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/05_T1_67b4c062170111edae5c003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/05_T1_67b4c062170111edae5c003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/05_T1_67b4c062170111edae5c003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/05_T1_67b4c062170111edae5c003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/05_T1_67b4c062170111edae5c003053fc6914_VR03.csv.gz
# Debug: Extracted filename: 05_T2_c9545d4e171211ed958f003053fc6914_VR03.csv.gz
# Debug: Split parts: ['05', 'T2', 'c9545d4e171211ed958f003053fc6914', 'VR03.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/05_T2_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/05_T2_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/05_T2_c9545d4e171211ed958f003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/05_T2_c9545d4e171211ed958f003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/05_T2_c9545d4e171211ed958f003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/05_T2_c9545d4e171211ed958f003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/05_T2_c9545d4e171211ed958f003053fc6914_VR03.csv.gz
# Debug: Extracted filename: 05_T3_241f2054172411ed958f003053fc6914_VR03.csv.gz
# Debug: Split parts: ['05', 'T3', '241f2054172411ed958f003053fc6914', 'VR03.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/05_T3_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/05_T3_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/05_T3_241f2054172411ed958f003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/05_T3_241f2054172411ed958f003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/05_T3_241f2054172411ed958f003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/05_T3_241f2054172411ed958f003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/05_T3_241f2054172411ed958f003053fc6914_VR03.csv.gz
# Debug: Extracted filename: 06_T1_6a4b129a170111ed8d15003053fc8758_VR04.csv.gz
# Debug: Split parts: ['06', 'T1', '6a4b129a170111ed8d15003053fc8758', 'VR04.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/06_T1_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/06_T1_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/06_T1_6a4b129a170111ed8d15003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/06_T1_6a4b129a170111ed8d15003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/06_T1_6a4b129a170111ed8d15003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/06_T1_6a4b129a170111ed8d15003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/06_T1_6a4b129a170111ed8d15003053fc8758_VR04.csv.gz
# Debug: Extracted filename: 06_T2_cacaadb8171211ed84c4003053fc8758_VR04.csv.gz
# Debug: Split parts: ['06', 'T2', 'cacaadb8171211ed84c4003053fc8758', 'VR04.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/06_T2_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/06_T2_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/06_T2_cacaadb8171211ed84c4003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/06_T2_cacaadb8171211ed84c4003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/06_T2_cacaadb8171211ed84c4003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/06_T2_cacaadb8171211ed84c4003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/06_T2_cacaadb8171211ed84c4003053fc8758_VR04.csv.gz
# Debug: Extracted filename: 06_T3_25b64e56172411ed84c4003053fc8758_VR04.csv.gz
# Debug: Split parts: ['06', 'T3', '25b64e56172411ed84c4003053fc8758', 'VR04.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/06_T3_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/06_T3_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/06_T3_25b64e56172411ed84c4003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/06_T3_25b64e56172411ed84c4003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/06_T3_25b64e56172411ed84c4003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/06_T3_25b64e56172411ed84c4003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/06_T3_25b64e56172411ed84c4003053fc8758_VR04.csv.gz
# Debug: Extracted filename: 07_T1_6bd905ea170111ed9cab003053fc769c_VR05.csv.gz
# Debug: Split parts: ['07', 'T1', '6bd905ea170111ed9cab003053fc769c', 'VR05.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/07_T1_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/07_T1_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/07_T1_6bd905ea170111ed9cab003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/07_T1_6bd905ea170111ed9cab003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/07_T1_6bd905ea170111ed9cab003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/07_T1_6bd905ea170111ed9cab003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/07_T1_6bd905ea170111ed9cab003053fc769c_VR05.csv.gz
# Debug: Extracted filename: 07_T2_cc25ad02171211edbaef003053fc769c_VR05.csv.gz
# Debug: Split parts: ['07', 'T2', 'cc25ad02171211edbaef003053fc769c', 'VR05.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/07_T2_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/07_T2_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/07_T2_cc25ad02171211edbaef003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/07_T2_cc25ad02171211edbaef003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/07_T2_cc25ad02171211edbaef003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/07_T2_cc25ad02171211edbaef003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/07_T2_cc25ad02171211edbaef003053fc769c_VR05.csv.gz
# Debug: Extracted filename: 07_T3_26cd344e172411edbaef003053fc769c_VR05.csv.gz
# Debug: Split parts: ['07', 'T3', '26cd344e172411edbaef003053fc769c', 'VR05.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/07_T3_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/07_T3_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/07_T3_26cd344e172411edbaef003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/07_T3_26cd344e172411edbaef003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/07_T3_26cd344e172411edbaef003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/07_T3_26cd344e172411edbaef003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/07_T3_26cd344e172411edbaef003053fc769c_VR05.csv.gz
# Debug: Extracted filename: 08_T1_6d7f9f76170111ed823c003053fc7678_VR06.csv.gz
# Debug: Split parts: ['08', 'T1', '6d7f9f76170111ed823c003053fc7678', 'VR06.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/08_T1_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/08_T1_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/08_T1_6d7f9f76170111ed823c003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/08_T1_6d7f9f76170111ed823c003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/08_T1_6d7f9f76170111ed823c003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/08_T1_6d7f9f76170111ed823c003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/08_T1_6d7f9f76170111ed823c003053fc7678_VR06.csv.gz
# Debug: Extracted filename: 08_T2_cd8c5eac171211ed8649003053fc7678_VR06.csv.gz
# Debug: Split parts: ['08', 'T2', 'cd8c5eac171211ed8649003053fc7678', 'VR06.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/08_T2_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/08_T2_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/08_T2_cd8c5eac171211ed8649003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/08_T2_cd8c5eac171211ed8649003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/08_T2_cd8c5eac171211ed8649003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/08_T2_cd8c5eac171211ed8649003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/08_T2_cd8c5eac171211ed8649003053fc7678_VR06.csv.gz
# Debug: Extracted filename: 08_T3_27ed0930172411ed8649003053fc7678_VR06.csv.gz
# Debug: Split parts: ['08', 'T3', '27ed0930172411ed8649003053fc7678', 'VR06.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/08_T3_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/08_T3_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/08_T3_27ed0930172411ed8649003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/08_T3_27ed0930172411ed8649003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/08_T3_27ed0930172411ed8649003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/08_T3_27ed0930172411ed8649003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/08_T3_27ed0930172411ed8649003053fc7678_VR06.csv.gz
# Debug: Extracted filename: 09_T1_ff3bc43217cc11ed8a8e003053fc6914_VR03.csv.gz
# Debug: Split parts: ['09', 'T1', 'ff3bc43217cc11ed8a8e003053fc6914', 'VR03.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/09_T1_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/09_T1_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/09_T1_ff3bc43217cc11ed8a8e003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/09_T1_ff3bc43217cc11ed8a8e003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/09_T1_ff3bc43217cc11ed8a8e003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/09_T1_ff3bc43217cc11ed8a8e003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/09_T1_ff3bc43217cc11ed8a8e003053fc6914_VR03.csv.gz
# Debug: Extracted filename: 09_T2_c5c37d2817de11ed95a0003053fc6914_VR03.csv.gz
# Debug: Split parts: ['09', 'T2', 'c5c37d2817de11ed95a0003053fc6914', 'VR03.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/09_T2_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/09_T2_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/09_T2_c5c37d2817de11ed95a0003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/09_T2_c5c37d2817de11ed95a0003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/09_T2_c5c37d2817de11ed95a0003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/09_T2_c5c37d2817de11ed95a0003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/09_T2_c5c37d2817de11ed95a0003053fc6914_VR03.csv.gz
# Debug: Extracted filename: 09_T3_28c171b217f011ed90a7003053fc6914_VR03.csv.gz
# Debug: Split parts: ['09', 'T3', '28c171b217f011ed90a7003053fc6914', 'VR03.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/09_T3_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/09_T3_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/09_T3_28c171b217f011ed90a7003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/09_T3_28c171b217f011ed90a7003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/09_T3_28c171b217f011ed90a7003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/09_T3_28c171b217f011ed90a7003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/09_T3_28c171b217f011ed90a7003053fc6914_VR03.csv.gz
# Debug: Extracted filename: 10_T1_0105bbb017cd11ed8887003053fc8758_VR04.csv.gz
# Debug: Split parts: ['10', 'T1', '0105bbb017cd11ed8887003053fc8758', 'VR04.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/10_T1_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/10_T1_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/10_T1_0105bbb017cd11ed8887003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/10_T1_0105bbb017cd11ed8887003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/10_T1_0105bbb017cd11ed8887003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/10_T1_0105bbb017cd11ed8887003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/10_T1_0105bbb017cd11ed8887003053fc8758_VR04.csv.gz
# Debug: Extracted filename: 10_T2_c6ec029c17de11ed96f1003053fc8758_VR04.csv.gz
# Debug: Split parts: ['10', 'T2', 'c6ec029c17de11ed96f1003053fc8758', 'VR04.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/10_T2_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/10_T2_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/10_T2_c6ec029c17de11ed96f1003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/10_T2_c6ec029c17de11ed96f1003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/10_T2_c6ec029c17de11ed96f1003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/10_T2_c6ec029c17de11ed96f1003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/10_T2_c6ec029c17de11ed96f1003053fc8758_VR04.csv.gz
# Debug: Extracted filename: 10_T3_2a1773b817f011ed855f003053fc8758_VR04.csv.gz
# Debug: Split parts: ['10', 'T3', '2a1773b817f011ed855f003053fc8758', 'VR04.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/10_T3_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/10_T3_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/10_T3_2a1773b817f011ed855f003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/10_T3_2a1773b817f011ed855f003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/10_T3_2a1773b817f011ed855f003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/10_T3_2a1773b817f011ed855f003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/10_T3_2a1773b817f011ed855f003053fc8758_VR04.csv.gz
# Debug: Extracted filename: 11_T1_02594efa17cd11ed97e1003053fc769c_VR05.csv.gz
# Debug: Split parts: ['11', 'T1', '02594efa17cd11ed97e1003053fc769c', 'VR05.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/11_T1_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/11_T1_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/11_T1_02594efa17cd11ed97e1003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/11_T1_02594efa17cd11ed97e1003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/11_T1_02594efa17cd11ed97e1003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/11_T1_02594efa17cd11ed97e1003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/11_T1_02594efa17cd11ed97e1003053fc769c_VR05.csv.gz
# Debug: Extracted filename: 11_T2_c7e21d9417de11ed9147003053fc769c_VR05.csv.gz
# Debug: Split parts: ['11', 'T2', 'c7e21d9417de11ed9147003053fc769c', 'VR05.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/11_T2_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/11_T2_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/11_T2_c7e21d9417de11ed9147003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/11_T2_c7e21d9417de11ed9147003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/11_T2_c7e21d9417de11ed9147003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/11_T2_c7e21d9417de11ed9147003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/11_T2_c7e21d9417de11ed9147003053fc769c_VR05.csv.gz
# Debug: Extracted filename: 11_T3_2b3f865417f011eda372003053fc769c_VR05.csv.gz
# Debug: Split parts: ['11', 'T3', '2b3f865417f011eda372003053fc769c', 'VR05.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/11_T3_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/11_T3_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/11_T3_2b3f865417f011eda372003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/11_T3_2b3f865417f011eda372003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/11_T3_2b3f865417f011eda372003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/11_T3_2b3f865417f011eda372003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/11_T3_2b3f865417f011eda372003053fc769c_VR05.csv.gz
# Debug: Extracted filename: 12_T1_03bc10e817cd11edac67003053fc7678_VR06.csv.gz
# Debug: Split parts: ['12', 'T1', '03bc10e817cd11edac67003053fc7678', 'VR06.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/12_T1_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/12_T1_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/12_T1_03bc10e817cd11edac67003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/12_T1_03bc10e817cd11edac67003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/12_T1_03bc10e817cd11edac67003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/12_T1_03bc10e817cd11edac67003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/12_T1_03bc10e817cd11edac67003053fc7678_VR06.csv.gz
# Debug: Extracted filename: 12_T2_c97009c817de11edbb92003053fc7678_VR06.csv.gz
# Debug: Split parts: ['12', 'T2', 'c97009c817de11edbb92003053fc7678', 'VR06.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/12_T2_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/12_T2_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/12_T2_c97009c817de11edbb92003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/12_T2_c97009c817de11edbb92003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/12_T2_c97009c817de11edbb92003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/12_T2_c97009c817de11edbb92003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/12_T2_c97009c817de11edbb92003053fc7678_VR06.csv.gz
# Debug: Extracted filename: 12_T3_2c97e7ee17f011ed9335003053fc7678_VR06.csv.gz
# Debug: Split parts: ['12', 'T3', '2c97e7ee17f011ed9335003053fc7678', 'VR06.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/12_T3_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/12_T3_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/12_T3_2c97e7ee17f011ed9335003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/12_T3_2c97e7ee17f011ed9335003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/12_T3_2c97e7ee17f011ed9335003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/12_T3_2c97e7ee17f011ed9335003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/12_T3_2c97e7ee17f011ed9335003053fc7678_VR06.csv.gz
# Debug: Extracted filename: 13_T1_0f1550c0189b11ed86af003053fc6914_VR03.csv.gz
# Debug: Split parts: ['13', 'T1', '0f1550c0189b11ed86af003053fc6914', 'VR03.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/13_T1_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/13_T1_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/13_T1_0f1550c0189b11ed86af003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/13_T1_0f1550c0189b11ed86af003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/13_T1_0f1550c0189b11ed86af003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/13_T1_0f1550c0189b11ed86af003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/13_T1_0f1550c0189b11ed86af003053fc6914_VR03.csv.gz
# Debug: Extracted filename: 13_T2_58c2566218ac11ed86af003053fc6914_VR03.csv.gz
# Debug: Split parts: ['13', 'T2', '58c2566218ac11ed86af003053fc6914', 'VR03.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/13_T2_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/13_T2_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/13_T2_58c2566218ac11ed86af003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/13_T2_58c2566218ac11ed86af003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/13_T2_58c2566218ac11ed86af003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/13_T2_58c2566218ac11ed86af003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/13_T2_58c2566218ac11ed86af003053fc6914_VR03.csv.gz
# Debug: Extracted filename: 13_T3_ac03031218c011ed86af003053fc6914_VR03.csv.gz
# Debug: Split parts: ['13', 'T3', 'ac03031218c011ed86af003053fc6914', 'VR03.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/13_T3_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/13_T3_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/13_T3_ac03031218c011ed86af003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/13_T3_ac03031218c011ed86af003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/13_T3_ac03031218c011ed86af003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/13_T3_ac03031218c011ed86af003053fc6914_VR03.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/13_T3_ac03031218c011ed86af003053fc6914_VR03.csv.gz
# Debug: Extracted filename: 14_T1_107fc5a8189b11edb396003053fc8758_VR04.csv.gz
# Debug: Split parts: ['14', 'T1', '107fc5a8189b11edb396003053fc8758', 'VR04.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/14_T1_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/14_T1_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/14_T1_107fc5a8189b11edb396003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/14_T1_107fc5a8189b11edb396003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/14_T1_107fc5a8189b11edb396003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/14_T1_107fc5a8189b11edb396003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/14_T1_107fc5a8189b11edb396003053fc8758_VR04.csv.gz
# Debug: Extracted filename: 14_T2_5a444d9c18ac11edb396003053fc8758_VR04.csv.gz
# Debug: Split parts: ['14', 'T2', '5a444d9c18ac11edb396003053fc8758', 'VR04.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/14_T2_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/14_T2_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/14_T2_5a444d9c18ac11edb396003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/14_T2_5a444d9c18ac11edb396003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/14_T2_5a444d9c18ac11edb396003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/14_T2_5a444d9c18ac11edb396003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/14_T2_5a444d9c18ac11edb396003053fc8758_VR04.csv.gz
# Debug: Extracted filename: 14_T3_ad840cfe18c011edb396003053fc8758_VR04.csv.gz
# Debug: Split parts: ['14', 'T3', 'ad840cfe18c011edb396003053fc8758', 'VR04.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/14_T3_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/14_T3_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/14_T3_ad840cfe18c011edb396003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/14_T3_ad840cfe18c011edb396003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/14_T3_ad840cfe18c011edb396003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/14_T3_ad840cfe18c011edb396003053fc8758_VR04.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/14_T3_ad840cfe18c011edb396003053fc8758_VR04.csv.gz
# Debug: Extracted filename: 15_T1_11e947b6189b11ed81af003053fc769c_VR05.csv.gz
# Debug: Split parts: ['15', 'T1', '11e947b6189b11ed81af003053fc769c', 'VR05.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/15_T1_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/15_T1_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/15_T1_11e947b6189b11ed81af003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/15_T1_11e947b6189b11ed81af003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/15_T1_11e947b6189b11ed81af003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/15_T1_11e947b6189b11ed81af003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/15_T1_11e947b6189b11ed81af003053fc769c_VR05.csv.gz
# Debug: Extracted filename: 15_T2_5b7ccb9418ac11ed81af003053fc769c_VR05.csv.gz
# Debug: Split parts: ['15', 'T2', '5b7ccb9418ac11ed81af003053fc769c', 'VR05.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/15_T2_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/15_T2_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/15_T2_5b7ccb9418ac11ed81af003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/15_T2_5b7ccb9418ac11ed81af003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/15_T2_5b7ccb9418ac11ed81af003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/15_T2_5b7ccb9418ac11ed81af003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/15_T2_5b7ccb9418ac11ed81af003053fc769c_VR05.csv.gz
# Debug: Extracted filename: 15_T3_aed4ada218c011ed81af003053fc769c_VR05.csv.gz
# Debug: Split parts: ['15', 'T3', 'aed4ada218c011ed81af003053fc769c', 'VR05.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/15_T3_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/15_T3_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/15_T3_aed4ada218c011ed81af003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/15_T3_aed4ada218c011ed81af003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/15_T3_aed4ada218c011ed81af003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/15_T3_aed4ada218c011ed81af003053fc769c_VR05.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/15_T3_aed4ada218c011ed81af003053fc769c_VR05.csv.gz
# Debug: Extracted filename: 16_T1_12f5b036189b11ed9814003053fc7678_VR06.csv.gz
# Debug: Split parts: ['16', 'T1', '12f5b036189b11ed9814003053fc7678', 'VR06.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/16_T1_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/16_T1_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/16_T1_12f5b036189b11ed9814003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/16_T1_12f5b036189b11ed9814003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/16_T1_12f5b036189b11ed9814003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/16_T1_12f5b036189b11ed9814003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/16_T1_12f5b036189b11ed9814003053fc7678_VR06.csv.gz
# Debug: Extracted filename: 16_T2_5d02270218ac11ed9814003053fc7678_VR06.csv.gz
# Debug: Split parts: ['16', 'T2', '5d02270218ac11ed9814003053fc7678', 'VR06.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/16_T2_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/16_T2_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/16_T2_5d02270218ac11ed9814003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/16_T2_5d02270218ac11ed9814003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/16_T2_5d02270218ac11ed9814003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/16_T2_5d02270218ac11ed9814003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/16_T2_5d02270218ac11ed9814003053fc7678_VR06.csv.gz
# Debug: Extracted filename: 16_T3_b004b06418c011ed9814003053fc7678_VR06.csv.gz
# Debug: Split parts: ['16', 'T3', 'b004b06418c011ed9814003053fc7678', 'VR06.csv.gz']
# Debug: Saving dataframe to /home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/16_T3_df_processed-data.csv
# Dataframe saved as '/home/kkumari/PhD/fish-data/processed-data-long-term-free-swim/16_T3_df_processed-data.csv'
# Skipping non-dataframe item for key: peaks in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/16_T3_b004b06418c011ed9814003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: peak_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/16_T3_b004b06418c011ed9814003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: wrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/16_T3_b004b06418c011ed9814003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: unwrapped_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/16_T3_b004b06418c011ed9814003053fc7678_VR06.csv.gz
# Skipping non-dataframe item for key: cumulative_angles in nested dict of /home/kkumari/PhD/fish-data/long-term-free-swim/16_T3_b004b06418c011ed9814003053fc7678_VR06.csv.gz
